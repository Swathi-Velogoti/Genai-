# %%
# !pip show torch
# Out:
# Name: torch
# Version: 2.2.2
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3
# Location: /Applications/anaconda3/lib/python3.12/site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: torchaudio, torchvision

# %%
import sys
print(sys.executable)  # Shows the current Python path
# Out:
# /Applications/anaconda3/bin/python

# %%
# !pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /Applications/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: torchvision in /Applications/anaconda3/lib/python3.12/site-packages (0.17.2)
# Requirement already satisfied: torchaudio in /Applications/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: filelock in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.local/lib/python3.12/site-packages (from torch) (4.13.0)
# Requirement already satisfied: sympy in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: numpy in ./.local/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Applications/anaconda3/lib/python3.12/site-packages (from torchvision) (10.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.local/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Applications/anaconda3/lib/python3.12/site-packages (from sympy->torch) (1.3.0)

# %%
# !pip 

import torch
import torch.nn as nn # neural network
import torch.optim as optim # apply optimization (adam,nadam)
import matplotlib.pyplot as plt # data visualization
# Out:
# Usage:
#   pip <command> [options]
#
# Commands:
#   install                     Install packages.
#   download                    Download packages.
#   uninstall                   Uninstall packages.
#   freeze                      Output installed packages in requirements format.
#   inspect                     Inspect the python environment.
#   list                        List installed packages.
#   show                        Show information about installed packages.
#   check                       Verify installed packages have compatible dependencies.
#   config                      Manage local and global configuration.
#   search                      Search PyPI for packages.
#   cache                       Inspect and manage pip's wheel cache.
#   index                       Inspect information available from package indexes.
#   wheel                       Build wheels from your requirements.
#   hash                        Compute hashes of package archives.
#   completion                  A helper command used for command completion.
#   debug                       Show information useful for debugging.
#   help                        Show help for commands.
#
# General Options:
#   -h, --help                  Show help.
#   --debug                     Let unhandled exceptions propagate outside the
#                               main subroutine, instead of logging them to
#                               stderr.
#   --isolated                  Run pip in an isolated mode, ignoring
#                               environment variables and user configuration.
#   --require-virtualenv        Allow pip to only run in a virtual environment;
#                               exit with an error otherwise.
#   --python <python>           Run pip with the specified Python interpreter.
#   -v, --verbose               Give more output. Option is additive, and can be
#                               used up to 3 times.
#   -V, --version               Show version and exit.
#   -q, --quiet                 Give less output. Option is additive, and can be
#                               used up to 3 times (corresponding to WARNING,
#                               ERROR, and CRITICAL logging levels).
#   --log <path>                Path to a verbose appending log.
#   --no-input                  Disable prompting for input.
#   --keyring-provider <keyring_provider>
#                               Enable the credential lookup via the keyring
#                               library if user input is allowed. Specify which
#                               mechanism to use [disabled, import, subprocess].
#                               (default: disabled)
#   --proxy <proxy>             Specify a proxy in the form
#                               scheme://[user:passwd@]proxy.server:port.
#   --retries <retries>         Maximum number of retries each connection should
#                               attempt (default 5 times).
#   --timeout <sec>             Set the socket timeout (default 15 seconds).
#   --exists-action <action>    Default action when a path already exists:
#                               (s)witch, (i)gnore, (w)ipe, (b)ackup, (a)bort.
#   --trusted-host <hostname>   Mark this host or host:port pair as trusted,
#                               even though it does not have valid or any HTTPS.
#   --cert <path>               Path to PEM-encoded CA certificate bundle. If
#                               provided, overrides the default. See 'SSL
#                               Certificate Verification' in pip documentation
#                               for more information.
#   --client-cert <path>        Path to SSL client certificate, a single file
#                               containing the private key and the certificate
#                               in PEM format.
#   --cache-dir <dir>           Store the cache data in <dir>.
#   --no-cache-dir              Disable the cache.
#   --disable-pip-version-check
#                               Don't periodically check PyPI to determine
#                               whether a new version of pip is available for
#                               download. Implied with --no-index.
#   --no-color                  Suppress colored output.
#   --no-python-version-warning
#                               Silence deprecation warnings for upcoming
#                               unsupported Pythons.
#   --use-feature <feature>     Enable new functionality, that may be backward
#                               incompatible.
#   --use-deprecated <feature>  Enable deprecated functionality, that will be
#                               removed in the future.

# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /Applications/anaconda3/lib/python3.12/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /Applications/anaconda3/lib/python3.12/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /Applications/anaconda3/lib/python3.12/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in ./.local/lib/python3.12/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /Applications/anaconda3/lib/python3.12/site-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /Applications/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /Applications/anaconda3/lib/python3.12/site-packages (from requests[socks]->gdown) (1.7.1)

# %%
# !pip install gdown

import gdown

file_id = "1JFWcvhzSN5WpL5zqeubVxE9PqpaAPOps"
file_url = f"https://drive.google.com/uc?export=download&id={file_id}"
output = "downloaded_file.txt"

gdown.download(file_url, output, quiet=False)

with open(output, "r", encoding="utf-8") as f:
    text = f.read()
    print(text)
# Out:
# Requirement already satisfied: gdown in /Applications/anaconda3/lib/python3.12/site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /Applications/anaconda3/lib/python3.12/site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /Applications/anaconda3/lib/python3.12/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in ./.local/lib/python3.12/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /Applications/anaconda3/lib/python3.12/site-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in /Applications/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./.local/lib/python3.12/site-packages (from requests[socks]->gdown) (2025.1.31)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in
# \
# \cb3 His dedication to his duties can be gauged from the fact that he died while delivering a lecture to students in the Indian Institute of Management in Shillong, Meghalaya after a sudden cardiac arrest on July 27, 2015 at the age of 83. He was an outstanding scientist and a pioneer engineer who devoted his entire life to the nation and died while serving it. India continues to miss this great scientist as his traits and words of wisdom keep on inspiring one and all.\cb1 \
# }

# %%
print("length of dataset in characters: ", len(text))
# Out:
# length of dataset in characters:  4830

# %%
# let's look at the first 1000 characters
print(text[:1000])
# Out:
# cb3 This was stated by visionary Dr. A.P.J. Abdul Kalam, the 11th President of India at a jam-packed hall in Kolkata on January 2, 2003 when he inspired thousands of school children to dream, to dream big, and let those dreams culminate in thoughts and actions. \'93Dream is not that which you see while sleeping, it is something that does not let you sleep,\'94 the \'91people\'92s President\'92 had elaborated later.\cb1 \
# \
# \cb3 Dr. Avul Pakir Jainulabdeen Abdul Kalam, internationally known as the \'93Missile Man of India\'94, was born on  October 15, 1931 at Dhanushkodi in Rameswaram district of Tamil Nadu. He got his early education in his hometown, after which he graduated in science from St. Joseph\'92s College, Tiruchi. Thereafter, Dr. Kalam took his Diploma in Aeronautical Engineering from Madras Institute of Technology in 1954.\cb1 \
# \
# \cb3 Dr. Kalam started his career with the Defence Research & Development Organisation (DRDO) in 1958 and served as a senior Scientific Assistant

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
print(''.join(chars))
print(vocab_size)
# Out:
#  &'(),-.0123456789ABCDEFGHIJKLMNOPRSTUVW\abcdefghijklmnopqrstuvwxy}
# 68

# %%
# !pip install torch
import torch
# let's now encode the entire text dataset and store it into a torch.Tensor
data = torch.tensor(encode(text), dtype=torch.long)
print(data.shape, data.dtype)
print(data[:1000]) # the 1000 characters we looked at earier will to the GPT look like this
# Out:
# Requirement already satisfied: torch in /Applications/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: filelock in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./.local/lib/python3.12/site-packages (from torch) (4.13.0)
# Requirement already satisfied: sympy in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (1.13.2)
# Requirement already satisfied: networkx in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /Applications/anaconda3/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.local/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Applications/anaconda3/lib/python3.12/site-packages (from sympy->torch) (1.3.0)
# torch.Size([4830]) torch.int64
# tensor([ 0, 44, 43, 12,  1, 37, 49, 50, 60,  1, 64, 42, 60,  1, 60, 61, 42, 61,
#         46, 45,  1, 43, 66,  1, 63, 50, 60, 50, 56, 55, 42, 59, 66,  1, 22, 59,
#          8,  1, 19,  8, 34,  8, 28,  8,  1, 19, 43, 45, 62, 53,  1, 29, 42, 53,
#         42, 54,  6,  1, 61, 49, 46,  1, 10, 10, 61, 49,  1, 34, 59, 46, 60, 50,
#         45, 46, 55, 61,  1, 56, 47,  1, 27, 55, 45, 50, 42,  1, 42, 61,  1, 42,
#         50,  1, 50, 55,  1, 35, 42, 54, 46, 60, 64, 42, 59, 42, 54,  1, 45, 50,
#         60, 61, 59, 50, 44, 61,  1, 56, 47,  1, 37, 42, 54, 50, 53,  1, 32, 42,
#         45, 62,  8,  1, 26, 46,  1, 48, 56, 61,  1, 49, 50, 60,  1, 46, 42, 59,
#         53, 66,  1, 46, 45, 62, 44, 42, 61, 50, 56, 55,  1, 50, 55,  1, 49, 50,
#         60,  1, 49, 56, 54, 46, 61, 56, 64, 55,  6,  1, 42, 47, 61, 46, 59,  1,
#         64, 49, 50, 44, 49,  1, 49, 46,  1, 48, 59, 42, 45, 62, 42, 61, 46, 45,
#          1, 50, 55,  1, 60, 44, 50, 46, 55, 44, 46,  1, 47, 59, 56, 54,  1, 36,
#         61,  8,  1, 28, 56, 60, 46, 57, 49, 41,  3, 18, 11, 60,  1, 21, 56, 53,
#         53, 46, 48, 46,  6,  1, 37, 50, 59, 62, 44, 49, 50,  8,  1, 37, 49, 46,
#         59, 46, 42, 47, 61, 46, 59,  6,  1, 22, 59,  8,  1, 29, 42, 53, 42, 54,
#          1, 61, 56, 56, 52,  1, 49, 50, 60,  1, 22, 50, 57, 53, 56, 54, 42,  1,
#         50, 55,  1, 19, 46, 59, 56, 55, 42, 62, 61, 50, 44, 42, 53,  1, 23, 55,
#         48, 50, 55, 46, 46, 59, 50, 55, 48,  1, 47, 59, 56, 54,  1, 31, 42, 45,
#         59, 42, 60,  1, 27, 55, 60, 61, 50, 61, 62, 61, 46,  1, 56, 47,  1, 37,
#         46, 44, 49, 55, 56, 53, 56, 48, 66,  1, 50, 55,  1, 10, 18, 14, 13,  8,
#         41, 44, 43, 10,  1, 41,  0, 41,  0, 41, 44, 43, 12,  1, 22, 59,  8,  1,
#         29, 42, 53, 42, 54,  1, 60, 61, 42, 59, 61, 46, 45,  1, 49, 50, 60,  1,
#         44, 42, 59, 46, 46, 59,  1, 64, 50, 61, 49,  1, 61, 49, 46,  1, 22, 46,
#         47, 46, 55, 44, 46,  1, 35, 46, 60, 46, 42, 59, 44, 49,  1,  2,  1, 22,
#         46, 63, 46, 53, 56, 57, 54, 46, 55, 61,  1, 33, 59, 48, 42, 55, 50, 60,
#         42, 61, 50, 56, 55,  1,  4, 22, 35, 22, 33,  5,  1, 50, 55,  1, 10, 18,
#         14, 17,  1, 42, 55, 45,  1, 60, 46, 59, 63, 46, 45,  1, 42, 60,  1, 42,
#          1, 60, 46, 55, 50, 56, 59,  1, 36, 44, 50, 46, 55, 61, 50, 47, 50, 44,
#          1, 19, 60, 60, 50, 60, 61, 42, 55, 61])

# %%
# Let's now split up the data into train and validation sets
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
block_size = 8
train_data[:block_size+1]
# Out:
# tensor([ 0, 44, 43, 12,  1, 37, 49, 50, 60])

# %%
x = train_data[:block_size]
y = train_data[1:block_size+1]
for t in range(block_size):
    context = x[:t+1]
    target = y[t]
    print(f"when input is {context} the target: {target}")
# Out:
# when input is tensor([0]) the target: 44
# when input is tensor([ 0, 44]) the target: 43
# when input is tensor([ 0, 44, 43]) the target: 12
# when input is tensor([ 0, 44, 43, 12]) the target: 1
# when input is tensor([ 0, 44, 43, 12,  1]) the target: 37
# when input is tensor([ 0, 44, 43, 12,  1, 37]) the target: 49
# when input is tensor([ 0, 44, 43, 12,  1, 37, 49]) the target: 50
# when input is tensor([ 0, 44, 43, 12,  1, 37, 49, 50]) the target: 60

# %%
torch.manual_seed(1337)
batch_size = 32 # how many independent sequences will we process in parallel?
block_size = 8 # what is the maximum context length for predictions?

def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    return x, y

xb, yb = get_batch('train')
print('inputs:')
print(xb.shape)
print(xb)
print('targets:')
print(yb.shape)
print(yb)

print('----')

for b in range(batch_size): # batch dimension
    for t in range(block_size): # time dimension
        context = xb[b, :t+1]
        target = yb[b,t]
        print(f"when input is {context.tolist()} the target: {target}")
# Out:
# inputs:
# torch.Size([32, 8])
# tensor([[56,  1, 49, 50, 60,  1, 60, 57],
#         [56, 52, 49, 42, 59, 42, 55,  6],
#         [ 1, 56, 47,  1, 42, 64, 42, 59],
#         [54, 43, 42,  8,  1, 40, 50, 61],
#         [55,  1, 61, 49, 56, 62, 48, 49],
#         [59, 42, 55,  6,  1, 35, 42, 51],
#         [ 1, 35, 42, 61, 55, 42, 41,  3],
#         [64, 42, 59, 45, 46, 45,  1, 34],
#         [54,  6,  1, 50, 55, 61, 46, 59],
#         [ 1, 51, 42, 54,  7, 57, 42, 44],
#         [62, 53,  1, 29, 42, 53, 42, 54],
#         [29, 42, 53, 42, 54,  1, 60, 61],
#         [ 1, 26, 56, 64, 46, 63, 46, 59],
#         [66,  1, 28, 56, 62, 59, 55, 46],
#         [42, 60, 60, 61, 50, 54, 46,  1],
#         [57, 42, 44, 52, 46, 45,  1, 49],
#         [57, 53, 42, 66, 50, 55, 48,  1],
#         [53, 60, 56,  1, 64, 46, 53, 53],
#         [46, 63, 46, 53, 56, 57, 54, 46],
#         [45, 62, 53,  1, 29, 42, 53, 42],
#         [42, 53, 42, 54,  6,  1, 50, 55],
#         [ 1, 50, 55,  1, 10, 18, 14, 17],
#         [61, 49, 50, 55, 48,  1, 61, 49],
#         [37, 49, 50, 60,  1, 64, 42, 60],
#         [ 1, 58, 62, 42, 53, 50, 61, 50],
#         [48, 66,  1, 50, 55,  1, 10, 18],
#         [ 1, 10, 18, 18, 17,  8,  1, 37],
#         [54,  1, 42, 60,  1, 61, 49, 46],
#         [49, 50, 48, 49, 46, 60, 61,  1],
#         [34, 59, 56, 51, 46, 44, 61,  1],
#         [61, 56, 56, 45,  1, 42, 60,  1],
#         [51, 56, 50, 55, 46, 45,  1, 27]])
# targets:
# torch.Size([32, 8])
# tensor([[ 1, 49, 50, 60,  1, 60, 57, 53],
#         [52, 49, 42, 59, 42, 55,  6,  1],
#         [56, 47,  1, 42, 64, 42, 59, 45],
#         [43, 42,  8,  1, 40, 50, 61, 49],
#         [ 1, 61, 49, 56, 62, 48, 49, 61],
#         [42, 55,  6,  1, 35, 42, 51, 42],
#         [35, 42, 61, 55, 42, 41,  3, 18],
#         [42, 59, 45, 46, 45,  1, 34, 42],
#         [ 6,  1, 50, 55, 61, 46, 59, 42],
#         [51, 42, 54,  7, 57, 42, 44, 52],
#         [53,  1, 29, 42, 53, 42, 54,  6],
#         [42, 53, 42, 54,  1, 60, 61, 42],
#         [26, 56, 64, 46, 63, 46, 59,  6],
#         [ 1, 28, 56, 62, 59, 55, 46, 66],
#         [60, 60, 61, 50, 54, 46,  1, 50],
#         [42, 44, 52, 46, 45,  1, 49, 42],
#         [53, 42, 66, 50, 55, 48,  1, 39],
#         [60, 56,  1, 64, 46, 53, 53,  1],
#         [63, 46, 53, 56, 57, 54, 46, 55],
#         [62, 53,  1, 29, 42, 53, 42, 54],
#         [53, 42, 54,  6,  1, 50, 55, 61],
#         [50, 55,  1, 10, 18, 14, 17,  1],
#         [49, 50, 55, 48,  1, 61, 49, 42],
#         [49, 50, 60,  1, 64, 42, 60,  1],
#         [58, 62, 42, 53, 50, 61, 50, 46],
#         [66,  1, 50, 55,  1, 10, 18, 14],
#         [10, 18, 18, 17,  8,  1, 37, 49],
#         [ 1, 42, 60,  1, 61, 49, 46,  1],
#         [50, 48, 49, 46, 60, 61,  1, 44],
#         [59, 56, 51, 46, 44, 61,  1, 22],
#         [56, 56, 45,  1, 42, 60,  1, 42],
#         [56, 50, 55, 46, 45,  1, 27, 55]])
# ----
# when input is [56] the target: 1
# when input is [56, 1] the target: 49
# when input is [56, 1, 49] the target: 50
# when input is [56, 1, 49, 50] the target: 60
# when input is [56, 1, 49, 50, 60] the target: 1
# when input is [56, 1, 49, 50, 60, 1] the target: 60
# when input is [56, 1, 49, 50, 60, 1, 60] the target: 57
# when input is [56, 1, 49, 50, 60, 1, 60, 57] the target: 53
# when input is [56] the target: 52
# when input is [56, 52] the target: 49
# when input is [56, 52, 49] the target: 42
# when input is [56, 52, 49, 42] the target: 59
# when input is [56, 52, 49, 42, 59] the target: 42
# when input is [56, 52, 49, 42, 59, 42] the target: 55
# when input is [56, 52, 49, 42, 59, 42, 55] the target: 6
# when input is [56, 52, 49, 42, 59, 42, 55, 6] the target: 1
# when input is [1] the target: 56
# when input is [1, 56] the target: 47
# when input is [1, 56, 47] the target: 1
# when input is [1, 56, 47, 1] the target: 42
# when input is [1, 56, 47, 1, 42] the target: 64
# when input is [1, 56, 47, 1, 42, 64] the target: 42
# when input is [1, 56, 47, 1, 42, 64, 42] the target: 59
# when input is [1, 56, 47, 1, 42, 64, 42, 59] the target: 45
# when input is [54] the target: 43
# when input is [54, 43] the target: 42
# when input is [54, 43, 42] the target: 8
# when input is [54, 43, 42, 8] the target: 1
# when input is [54, 43, 42, 8, 1] the target: 40
# when input is [54, 43, 42, 8, 1, 40] the target: 50
# when input is [54, 43, 42, 8, 1, 40, 50] the target: 61
# when input is [54, 43, 42, 8, 1, 40, 50, 61] the target: 49
# when input is [55] the target: 1
# when input is [55, 1] the target: 61
# when input is [55, 1, 61] the target: 49
# when input is [55, 1, 61, 49] the target: 56
# when input is [55, 1, 61, 49, 56] the target: 62
# when input is [55, 1, 61, 49, 56, 62] the target: 48
# when input is [55, 1, 61, 49, 56, 62, 48] the target: 49
# when input is [55, 1, 61, 49, 56, 62, 48, 49] the target: 61
# when input is [59] the target: 42
# when input is [59, 42] the target: 55
# when input is [59, 42, 55] the target: 6
# when input is [59, 42, 55, 6] the target: 1
# when input is [59, 42, 55, 6, 1] the target: 35
# when input is [59, 42, 55, 6, 1, 35] the target: 42
# when input is [59, 42, 55, 6, 1, 35, 42] the target: 51
# when input is [59, 42, 55, 6, 1, 35, 42, 51] the target: 42
# when input is [1] the target: 35
# when input is [1, 35] the target: 42
# when input is [1, 35, 42] the target: 61
# when input is [1, 35, 42, 61] the target: 55
# when input is [1, 35, 42, 61, 55] the target: 42
# when input is [1, 35, 42, 61, 55, 42] the target: 41
# when input is [1, 35, 42, 61, 55, 42, 41] the target: 3
# when input is [1, 35, 42, 61, 55, 42, 41, 3] the target: 18
# when input is [64] the target: 42
# when input is [64, 42] the target: 59
# when input is [64, 42, 59] the target: 45
# when input is [64, 42, 59, 45] the target: 46
# when input is [64, 42, 59, 45, 46] the target: 45
# when input is [64, 42, 59, 45, 46, 45] the target: 1
# when input is [64, 42, 59, 45, 46, 45, 1] the target: 34
# when input is [64, 42, 59, 45, 46, 45, 1, 34] the target: 42
# when input is [54] the target: 6
# when input is [54, 6] the target: 1
# when input is [54, 6, 1] the target: 50
# when input is [54, 6, 1, 50] the target: 55
# when input is [54, 6, 1, 50, 55] the target: 61
# when input is [54, 6, 1, 50, 55, 61] the target: 46
# when input is [54, 6, 1, 50, 55, 61, 46] the target: 59
# when input is [54, 6, 1, 50, 55, 61, 46, 59] the target: 42
# when input is [1] the target: 51
# when input is [1, 51] the target: 42
# when input is [1, 51, 42] the target: 54
# when input is [1, 51, 42, 54] the target: 7
# when input is [1, 51, 42, 54, 7] the target: 57
# when input is [1, 51, 42, 54, 7, 57] the target: 42
# when input is [1, 51, 42, 54, 7, 57, 42] the target: 44
# when input is [1, 51, 42, 54, 7, 57, 42, 44] the target: 52
# when input is [62] the target: 53
# when input is [62, 53] the target: 1
# when input is [62, 53, 1] the target: 29
# when input is [62, 53, 1, 29] the target: 42
# when input is [62, 53, 1, 29, 42] the target: 53
# when input is [62, 53, 1, 29, 42, 53] the target: 42
# when input is [62, 53, 1, 29, 42, 53, 42] the target: 54
# when input is [62, 53, 1, 29, 42, 53, 42, 54] the target: 6
# when input is [29] the target: 42
# when input is [29, 42] the target: 53
# when input is [29, 42, 53] the target: 42
# when input is [29, 42, 53, 42] the target: 54
# when input is [29, 42, 53, 42, 54] the target: 1
# when input is [29, 42, 53, 42, 54, 1] the target: 60
# when input is [29, 42, 53, 42, 54, 1, 60] the target: 61
# when input is [29, 42, 53, 42, 54, 1, 60, 61] the target: 42
# when input is [1] the target: 26
# when input is [1, 26] the target: 56
# when input is [1, 26, 56] the target: 64
# when input is [1, 26, 56, 64] the target: 46
# when input is [1, 26, 56, 64, 46] the target: 63
# when input is [1, 26, 56, 64, 46, 63] the target: 46
# when input is [1, 26, 56, 64, 46, 63, 46] the target: 59
# when input is [1, 26, 56, 64, 46, 63, 46, 59] the target: 6
# when input is [66] the target: 1
# when input is [66, 1] the target: 28
# when input is [66, 1, 28] the target: 56
# when input is [66, 1, 28, 56] the target: 62
# when input is [66, 1, 28, 56, 62] the target: 59
# when input is [66, 1, 28, 56, 62, 59] the target: 55
# when input is [66, 1, 28, 56, 62, 59, 55] the target: 46
# when input is [66, 1, 28, 56, 62, 59, 55, 46] the target: 66
# when input is [42] the target: 60
# when input is [42, 60] the target: 60
# when input is [42, 60, 60] the target: 61
# when input is [42, 60, 60, 61] the target: 50
# when input is [42, 60, 60, 61, 50] the target: 54
# when input is [42, 60, 60, 61, 50, 54] the target: 46
# when input is [42, 60, 60, 61, 50, 54, 46] the target: 1
# when input is [42, 60, 60, 61, 50, 54, 46, 1] the target: 50
# when input is [57] the target: 42
# when input is [57, 42] the target: 44
# when input is [57, 42, 44] the target: 52
# when input is [57, 42, 44, 52] the target: 46
# when input is [57, 42, 44, 52, 46] the target: 45
# when input is [57, 42, 44, 52, 46, 45] the target: 1
# when input is [57, 42, 44, 52, 46, 45, 1] the target: 49
# when input is [57, 42, 44, 52, 46, 45, 1, 49] the target: 42
# when input is [57] the target: 53
# when input is [57, 53] the target: 42
# when input is [57, 53, 42] the target: 66
# when input is [57, 53, 42, 66] the target: 50
# when input is [57, 53, 42, 66, 50] the target: 55
# when input is [57, 53, 42, 66, 50, 55] the target: 48
# when input is [57, 53, 42, 66, 50, 55, 48] the target: 1
# when input is [57, 53, 42, 66, 50, 55, 48, 1] the target: 39
# when input is [53] the target: 60
# when input is [53, 60] the target: 56
# when input is [53, 60, 56] the target: 1
# when input is [53, 60, 56, 1] the target: 64
# when input is [53, 60, 56, 1, 64] the target: 46
# when input is [53, 60, 56, 1, 64, 46] the target: 53
# when input is [53, 60, 56, 1, 64, 46, 53] the target: 53
# when input is [53, 60, 56, 1, 64, 46, 53, 53] the target: 1
# when input is [46] the target: 63
# when input is [46, 63] the target: 46
# when input is [46, 63, 46] the target: 53
# when input is [46, 63, 46, 53] the target: 56
# when input is [46, 63, 46, 53, 56] the target: 57
# when input is [46, 63, 46, 53, 56, 57] the target: 54
# when input is [46, 63, 46, 53, 56, 57, 54] the target: 46
# when input is [46, 63, 46, 53, 56, 57, 54, 46] the target: 55
# when input is [45] the target: 62
# when input is [45, 62] the target: 53
# when input is [45, 62, 53] the target: 1
# when input is [45, 62, 53, 1] the target: 29
# when input is [45, 62, 53, 1, 29] the target: 42
# when input is [45, 62, 53, 1, 29, 42] the target: 53
# when input is [45, 62, 53, 1, 29, 42, 53] the target: 42
# when input is [45, 62, 53, 1, 29, 42, 53, 42] the target: 54
# when input is [42] the target: 53
# when input is [42, 53] the target: 42
# when input is [42, 53, 42] the target: 54
# when input is [42, 53, 42, 54] the target: 6
# when input is [42, 53, 42, 54, 6] the target: 1
# when input is [42, 53, 42, 54, 6, 1] the target: 50
# when input is [42, 53, 42, 54, 6, 1, 50] the target: 55
# when input is [42, 53, 42, 54, 6, 1, 50, 55] the target: 61
# when input is [1] the target: 50
# when input is [1, 50] the target: 55
# when input is [1, 50, 55] the target: 1
# when input is [1, 50, 55, 1] the target: 10
# when input is [1, 50, 55, 1, 10] the target: 18
# when input is [1, 50, 55, 1, 10, 18] the target: 14
# when input is [1, 50, 55, 1, 10, 18, 14] the target: 17
# when input is [1, 50, 55, 1, 10, 18, 14, 17] the target: 1
# when input is [61] the target: 49
# when input is [61, 49] the target: 50
# when input is [61, 49, 50] the target: 55
# when input is [61, 49, 50, 55] the target: 48
# when input is [61, 49, 50, 55, 48] the target: 1
# when input is [61, 49, 50, 55, 48, 1] the target: 61
# when input is [61, 49, 50, 55, 48, 1, 61] the target: 49
# when input is [61, 49, 50, 55, 48, 1, 61, 49] the target: 42
# when input is [37] the target: 49
# when input is [37, 49] the target: 50
# when input is [37, 49, 50] the target: 60
# when input is [37, 49, 50, 60] the target: 1
# when input is [37, 49, 50, 60, 1] the target: 64
# when input is [37, 49, 50, 60, 1, 64] the target: 42
# when input is [37, 49, 50, 60, 1, 64, 42] the target: 60
# when input is [37, 49, 50, 60, 1, 64, 42, 60] the target: 1
# when input is [1] the target: 58
# when input is [1, 58] the target: 62
# when input is [1, 58, 62] the target: 42
# when input is [1, 58, 62, 42] the target: 53
# when input is [1, 58, 62, 42, 53] the target: 50
# when input is [1, 58, 62, 42, 53, 50] the target: 61
# when input is [1, 58, 62, 42, 53, 50, 61] the target: 50
# when input is [1, 58, 62, 42, 53, 50, 61, 50] the target: 46
# when input is [48] the target: 66
# when input is [48, 66] the target: 1
# when input is [48, 66, 1] the target: 50
# when input is [48, 66, 1, 50] the target: 55
# when input is [48, 66, 1, 50, 55] the target: 1
# when input is [48, 66, 1, 50, 55, 1] the target: 10
# when input is [48, 66, 1, 50, 55, 1, 10] the target: 18
# when input is [48, 66, 1, 50, 55, 1, 10, 18] the target: 14
# when input is [1] the target: 10
# when input is [1, 10] the target: 18
# when input is [1, 10, 18] the target: 18
# when input is [1, 10, 18, 18] the target: 17
# when input is [1, 10, 18, 18, 17] the target: 8
# when input is [1, 10, 18, 18, 17, 8] the target: 1
# when input is [1, 10, 18, 18, 17, 8, 1] the target: 37
# when input is [1, 10, 18, 18, 17, 8, 1, 37] the target: 49
# when input is [54] the target: 1
# when input is [54, 1] the target: 42
# when input is [54, 1, 42] the target: 60
# when input is [54, 1, 42, 60] the target: 1
# when input is [54, 1, 42, 60, 1] the target: 61
# when input is [54, 1, 42, 60, 1, 61] the target: 49
# when input is [54, 1, 42, 60, 1, 61, 49] the target: 46
# when input is [54, 1, 42, 60, 1, 61, 49, 46] the target: 1
# when input is [49] the target: 50
# when input is [49, 50] the target: 48
# when input is [49, 50, 48] the target: 49
# when input is [49, 50, 48, 49] the target: 46
# when input is [49, 50, 48, 49, 46] the target: 60
# when input is [49, 50, 48, 49, 46, 60] the target: 61
# when input is [49, 50, 48, 49, 46, 60, 61] the target: 1
# when input is [49, 50, 48, 49, 46, 60, 61, 1] the target: 44
# when input is [34] the target: 59
# when input is [34, 59] the target: 56
# when input is [34, 59, 56] the target: 51
# when input is [34, 59, 56, 51] the target: 46
# when input is [34, 59, 56, 51, 46] the target: 44
# when input is [34, 59, 56, 51, 46, 44] the target: 61
# when input is [34, 59, 56, 51, 46, 44, 61] the target: 1
# when input is [34, 59, 56, 51, 46, 44, 61, 1] the target: 22
# when input is [61] the target: 56
# when input is [61, 56] the target: 56
# when input is [61, 56, 56] the target: 45
# when input is [61, 56, 56, 45] the target: 1
# when input is [61, 56, 56, 45, 1] the target: 42
# when input is [61, 56, 56, 45, 1, 42] the target: 60
# when input is [61, 56, 56, 45, 1, 42, 60] the target: 1
# when input is [61, 56, 56, 45, 1, 42, 60, 1] the target: 42
# when input is [51] the target: 56
# when input is [51, 56] the target: 50
# when input is [51, 56, 50] the target: 55
# when input is [51, 56, 50, 55] the target: 46
# when input is [51, 56, 50, 55, 46] the target: 45
# when input is [51, 56, 50, 55, 46, 45] the target: 1
# when input is [51, 56, 50, 55, 46, 45, 1] the target: 27
# when input is [51, 56, 50, 55, 46, 45, 1, 27] the target: 55

# %%
class CharLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, num_layers=2):
        super(CharLSTM, self).__init__()
        self.embed = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_dim, vocab_size)

    def forward(self, x, hidden):
        x = self.embed(x)
        out, hidden = self.lstm(x, hidden)
        out = self.fc(out)
        return out, hidden

# %%
# Set hyperparameters
embedding_dim = 32
hidden_dim = 256
num_layers = 5
learning_rate = 0.001

model = CharLSTM(vocab_size, embedding_dim, hidden_dim, num_layers)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
def train_model(model, train_data, epochs=500):
    model.train()
    losses = []
    for epoch in range(epochs):
        hidden = (torch.zeros(num_layers, batch_size, hidden_dim),
                  torch.zeros(num_layers, batch_size, hidden_dim))
        x_batch, y_batch = get_batch('train')
        optimizer.zero_grad()
        output, hidden = model(x_batch, hidden)
        loss = criterion(output.view(-1, vocab_size), y_batch.view(-1))
        loss.backward()
        optimizer.step()
        losses.append(loss.item())
        print(f"Epoch {epoch+1}, Loss: {loss.item():.4f}")
    return losses

# %%
def generate_text(model, start_text, length=100, temperature=0.8):
    model.eval()
    input_seq = torch.tensor(encode(start_text), dtype=torch.long).unsqueeze(0)
    hidden = (torch.zeros(num_layers, 1, hidden_dim),
              torch.zeros(num_layers, 1, hidden_dim))
    generated_text = start_text

    for _ in range(length):
        output, hidden = model(input_seq, hidden)
        logits = output[:, -1, :] / temperature
        probs = torch.softmax(logits, dim=-1)
        next_char_idx = torch.multinomial(probs, num_samples=1).item()
        next_char = itos[next_char_idx]
        generated_text += next_char
        input_seq = torch.tensor([[next_char_idx]], dtype=torch.long)

    return generated_text

# %%
losses = train_model(model, train_data)
# Out:
# Epoch 1, Loss: 4.2266
# Epoch 428, Loss: 2.9902
# Epoch 429, Loss: 3.0430
# Epoch 430, Loss: 3.0522
# Epoch 431, Loss: 2.9733
# Epoch 432, Loss: 2.9786
# Epoch 433, Loss: 3.0540
# Epoch 434, Loss: 3.0321
# Epoch 435, Loss: 2.9894
# Epoch 436, Loss: 2.9964
# Epoch 437, Loss: 3.0271
# Epoch 438, Loss: 2.9637
# Epoch 439, Loss: 3.0708
# Epoch 440, Loss: 2.8900
# Epoch 441, Loss: 2.8823
# Epoch 442, Loss: 3.0128
# Epoch 443, Loss: 2.8946
# Epoch 444, Loss: 2.8702
# Epoch 445, Loss: 2.8566
# Epoch 446, Loss: 2.8526
# Epoch 447, Loss: 2.8824
# Epoch 448, Loss: 2.8834
# Epoch 449, Loss: 2.9957
# Epoch 450, Loss: 2.7725
# Epoch 451, Loss: 3.0382
# Epoch 452, Loss: 2.7516
# Epoch 453, Loss: 2.8232
# Epoch 454, Loss: 2.7936
# Epoch 455, Loss: 2.8355
# Epoch 456, Loss: 2.8901
# Epoch 457, Loss: 2.8576
# Epoch 458, Loss: 2.9528
# Epoch 459, Loss: 2.9407
# Epoch 460, Loss: 2.8360
# Epoch 461, Loss: 2.7708
# Epoch 462, Loss: 2.8059
# Epoch 463, Loss: 2.8167
# Epoch 464, Loss: 2.7786
# Epoch 465, Loss: 2.8611
# Epoch 466, Loss: 2.8297
# Epoch 467, Loss: 2.6881
# Epoch 468, Loss: 2.9298
# Epoch 469, Loss: 2.8494
# Epoch 470, Loss: 2.9341
# Epoch 471, Loss: 2.6463
# Epoch 472, Loss: 2.8876
# Epoch 473, Loss: 2.7327
# Epoch 474, Loss: 2.6636
# Epoch 475, Loss: 2.7341
# Epoch 476, Loss: 2.7851
# Epoch 477, Loss: 2.9112
# Epoch 478, Loss: 2.7896
# Epoch 479, Loss: 2.8174
# Epoch 480, Loss: 2.7136
# Epoch 481, Loss: 2.7502
# Epoch 482, Loss: 2.7927
# Epoch 483, Loss: 2.7014
# Epoch 484, Loss: 2.7146
# Epoch 485, Loss: 2.8360
# Epoch 486, Loss: 2.6249
# Epoch 487, Loss: 2.7899
# Epoch 488, Loss: 2.7115
# Epoch 489, Loss: 2.7011
# Epoch 490, Loss: 2.7959
# Epoch 491, Loss: 2.8532
# Epoch 492, Loss: 2.6675
# Epoch 493, Loss: 2.6788
# Epoch 494, Loss: 2.8720
# Epoch 495, Loss: 2.8956
# Epoch 496, Loss: 2.6982
# Epoch 497, Loss: 2.7615
# Epoch 498, Loss: 2.6562
# Epoch 499, Loss: 2.7136
# Epoch 500, Loss: 2.7603

# %%
plt.plot(losses, label='Training Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training Loss Curve')
plt.legend()
plt.show()

start_text = "cb3 This was stated by visionary Dr. A.P.J. Abdul Kalam, the"
generated_text = generate_text(model, start_text, temperature=1.0)
print("Generated Text:\n", generated_text)
# Out:
# Generated Text:
#  cb3 This was stated by visionary Dr. A.P.J. Abdul Kalam, theth i aAu Dufijias, Mlegt tih ems Irt frias A&lumhep  ac dinns ey o gaBhotanrhes ang feTig whetacurhe
